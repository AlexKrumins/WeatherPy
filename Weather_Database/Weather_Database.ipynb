# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_descrip = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description":city_weather_descrip
        })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chapais
# Processing Record 2 of Set 1 | guerrero negro
# Processing Record 3 of Set 1 | mount gambier
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | batang berjuntai
# Processing Record 11 of Set 1 | caucaia
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | eisenberg
# Processing Record 16 of Set 1 | ambovombe
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | klaksvik
# Processing Record 21 of Set 1 | daru
# Processing Record 22 of Set 1 | khandbari
# Processing Record 23 of Set 1 | narsimhapur
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | uwayl
# City not found. Skipping...
# Processing Record 26 of Set 1 | buerarema
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | beloha
# Processing Record 29 of Set 1 | grindavik
# Processing Record 30 of Set 1 | turukhansk
# Processing Record 31 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | zig
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | hanyang
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | lavrentiya
# Processing Record 40 of Set 1 | ronne
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | isangel
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 1 | sabha
# Processing Record 47 of Set 1 | abnub
# Processing Record 48 of Set 1 | santa cruz del sur
# Processing Record 49 of Set 1 | honiara
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | zhanaozen
# Processing Record 3 of Set 2 | mandera
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 2 | buala
# Processing Record 8 of Set 2 | ostrovnoy
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | fortuna
# Processing Record 12 of Set 2 | malinyi
# Processing Record 13 of Set 2 | ahipara
# Processing Record 14 of Set 2 | rodino
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | lisakovsk
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | mambatangan
# Processing Record 28 of Set 2 | berlevag
# Processing Record 29 of Set 2 | napa
# Processing Record 30 of Set 2 | kloulklubed
# Processing Record 31 of Set 2 | sucua
# Processing Record 32 of Set 2 | coahuayana
# Processing Record 33 of Set 2 | japura
# Processing Record 34 of Set 2 | codrington
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | putina
# Processing Record 38 of Set 2 | praia da vitoria
# Processing Record 39 of Set 2 | leningradskiy
# Processing Record 40 of Set 2 | gamboma
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | chicla
# Processing Record 43 of Set 2 | port augusta
# Processing Record 44 of Set 2 | cayenne
# Processing Record 45 of Set 2 | lompoc
# Processing Record 46 of Set 2 | rocha
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | ravenna
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | danielskuil
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | celestun
# Processing Record 5 of Set 3 | palauig
# Processing Record 6 of Set 3 | roald
# Processing Record 7 of Set 3 | dunda
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | hamilton
# Processing Record 11 of Set 3 | nicoya
# Processing Record 12 of Set 3 | necochea
# Processing Record 13 of Set 3 | neiafu
# Processing Record 14 of Set 3 | umm lajj
# Processing Record 15 of Set 3 | cidreira
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | lukulu
# Processing Record 19 of Set 3 | jimeta
# Processing Record 20 of Set 3 | hay river
# Processing Record 21 of Set 3 | barranca
# Processing Record 22 of Set 3 | katsuura
# Processing Record 23 of Set 3 | manzhouli
# Processing Record 24 of Set 3 | kupang
# Processing Record 25 of Set 3 | acarau
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | okhotsk
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | walvis bay
# Processing Record 30 of Set 3 | santa luzia
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | alyangula
# Processing Record 33 of Set 3 | fairbanks
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | yatou
# Processing Record 36 of Set 3 | laguna
# Processing Record 37 of Set 3 | teresina
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | tahe
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | mogadishu
# Processing Record 43 of Set 3 | sitka
# Processing Record 44 of Set 3 | rongcheng
# Processing Record 45 of Set 3 | axim
# Processing Record 46 of Set 3 | kulhudhuffushi
# Processing Record 47 of Set 3 | orhei
# Processing Record 48 of Set 3 | kapaa
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | nikolskoye
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | dzaoudzi
# Processing Record 3 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 4 | san andres
# Processing Record 5 of Set 4 | inhambane
# Processing Record 6 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | maningrida
# Processing Record 9 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | concarneau
# Processing Record 12 of Set 4 | hovd
# Processing Record 13 of Set 4 | mount isa
# Processing Record 14 of Set 4 | pangnirtung
# Processing Record 15 of Set 4 | concepcion
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | orneta
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 4 | namatanai
# Processing Record 22 of Set 4 | sento se
# City not found. Skipping...
# Processing Record 23 of Set 4 | maxixe
# Processing Record 24 of Set 4 | lima
# Processing Record 25 of Set 4 | leh
# Processing Record 26 of Set 4 | marawi
# Processing Record 27 of Set 4 | cururupu
# Processing Record 28 of Set 4 | sinazongwe
# Processing Record 29 of Set 4 | tveit
# Processing Record 30 of Set 4 | yulara
# Processing Record 31 of Set 4 | petropavlovka
# Processing Record 32 of Set 4 | padang
# Processing Record 33 of Set 4 | mbini
# Processing Record 34 of Set 4 | elk point
# Processing Record 35 of Set 4 | tadine
# Processing Record 36 of Set 4 | banda aceh
# Processing Record 37 of Set 4 | marsh harbour
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | dunedin
# Processing Record 40 of Set 4 | melville
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | mayumba
# Processing Record 43 of Set 4 | antofagasta
# Processing Record 44 of Set 4 | siparia
# Processing Record 45 of Set 4 | casablanca
# Processing Record 46 of Set 4 | carutapera
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | antalaha
# Processing Record 49 of Set 4 | crossville
# Processing Record 50 of Set 4 | lockhart
# Processing Record 1 of Set 5 | palafrugell
# Processing Record 2 of Set 5 | aksu
# Processing Record 3 of Set 5 | marrakesh
# Processing Record 4 of Set 5 | paris
# Processing Record 5 of Set 5 | tayu
# Processing Record 6 of Set 5 | mitsamiouli
# Processing Record 7 of Set 5 | dingle
# Processing Record 8 of Set 5 | millinocket
# Processing Record 9 of Set 5 | provideniya
# Processing Record 10 of Set 5 | cabo san lucas
# Processing Record 11 of Set 5 | muscat
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | los llanos de aridane
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | aranda de duero
# Processing Record 16 of Set 5 | chikoy
# City not found. Skipping...
# Processing Record 17 of Set 5 | meulaboh
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | kargopol
# Processing Record 21 of Set 5 | kirillov
# Processing Record 22 of Set 5 | salinas
# Processing Record 23 of Set 5 | ganzhou
# Processing Record 24 of Set 5 | faanui
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 5 | san pedro
# Processing Record 28 of Set 5 | moose factory
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 5 | karratha
# Processing Record 33 of Set 5 | fort william
# Processing Record 34 of Set 5 | scarborough
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | newton abbot
# Processing Record 37 of Set 5 | oranjestad
# Processing Record 38 of Set 5 | vagur
# Processing Record 39 of Set 5 | panguiranan
# Processing Record 40 of Set 5 | mirador
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | warrington
# Processing Record 43 of Set 5 | maldonado
# Processing Record 44 of Set 5 | anadyr
# Processing Record 45 of Set 5 | pokhara
# Processing Record 46 of Set 5 | lagoa
# Processing Record 47 of Set 5 | bumba
# Processing Record 48 of Set 5 | alice springs
# Processing Record 49 of Set 5 | bowen
# Processing Record 50 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | thalgau
# Processing Record 2 of Set 6 | torbay
# Processing Record 3 of Set 6 | mahajanga
# Processing Record 4 of Set 6 | cockburn town
# Processing Record 5 of Set 6 | kichera
# Processing Record 6 of Set 6 | asau
# Processing Record 7 of Set 6 | fethiye
# Processing Record 8 of Set 6 | trinidad
# Processing Record 9 of Set 6 | san juan del sur
# Processing Record 10 of Set 6 | latung
# Processing Record 11 of Set 6 | nagato
# Processing Record 12 of Set 6 | dwarka
# Processing Record 13 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 6 | touros
# Processing Record 15 of Set 6 | juneau
# Processing Record 16 of Set 6 | usinsk
# Processing Record 17 of Set 6 | wanning
# Processing Record 18 of Set 6 | ampanihy
# Processing Record 19 of Set 6 | shwebo
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | mareeba
# Processing Record 22 of Set 6 | cap-aux-meules
# Processing Record 23 of Set 6 | polovinnoye
# Processing Record 24 of Set 6 | ornskoldsvik
# Processing Record 25 of Set 6 | panshi
# Processing Record 26 of Set 6 | oranjemund
# Processing Record 27 of Set 6 | gagino
# Processing Record 28 of Set 6 | bandarbeyla
# Processing Record 29 of Set 6 | gamba
# Processing Record 30 of Set 6 | paita
# Processing Record 31 of Set 6 | clyde river
# Processing Record 32 of Set 6 | mikkeli
# Processing Record 33 of Set 6 | lasa
# Processing Record 34 of Set 6 | huarmey
# Processing Record 35 of Set 6 | nishihara
# Processing Record 36 of Set 6 | margate
# Processing Record 37 of Set 6 | tateyama
# Processing Record 38 of Set 6 | khromtau
# Processing Record 39 of Set 6 | goure
# Processing Record 40 of Set 6 | rosetta
# Processing Record 41 of Set 6 | luganville
# Processing Record 42 of Set 6 | troitsk
# Processing Record 43 of Set 6 | zarichne
# Processing Record 44 of Set 6 | upernavik
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | parvatsar
# Processing Record 47 of Set 6 | emba
# Processing Record 48 of Set 6 | atar
# Processing Record 49 of Set 6 | shenjiamen
# Processing Record 50 of Set 6 | markova
# Processing Record 1 of Set 7 | aklavik
# Processing Record 2 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 7 | adrar
# Processing Record 4 of Set 7 | tutoia
# Processing Record 5 of Set 7 | harwich
# Processing Record 6 of Set 7 | korla
# Processing Record 7 of Set 7 | trincomalee
# Processing Record 8 of Set 7 | saint-augustin
# Processing Record 9 of Set 7 | niquero
# Processing Record 10 of Set 7 | metro
# Processing Record 11 of Set 7 | jiaozuo
# Processing Record 12 of Set 7 | pacific grove
# Processing Record 13 of Set 7 | sumkino
# Processing Record 14 of Set 7 | maniitsoq
# Processing Record 15 of Set 7 | olga
# Processing Record 16 of Set 7 | hobbs
# Processing Record 17 of Set 7 | anton lizardo
# Processing Record 18 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 7 | broken hill
# Processing Record 20 of Set 7 | dunmore town
# Processing Record 21 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 7 | saint george
# Processing Record 23 of Set 7 | edd
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | comodoro rivadavia
# Processing Record 26 of Set 7 | coos bay
# Processing Record 27 of Set 7 | vestmanna
# Processing Record 28 of Set 7 | sirur
# Processing Record 29 of Set 7 | najran
# Processing Record 30 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 7 | ambatofinandrahana
# Processing Record 32 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 7 | kieta
# Processing Record 34 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 7 | shakawe
# Processing Record 36 of Set 7 | georgetown
# Processing Record 37 of Set 7 | carnarvon
# Processing Record 38 of Set 7 | talcahuano
# Processing Record 39 of Set 7 | constitucion
# Processing Record 40 of Set 7 | vao
# Processing Record 41 of Set 7 | kantang
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | cabedelo
# Processing Record 44 of Set 7 | skelleftea
# Processing Record 45 of Set 7 | namibe
# Processing Record 46 of Set 7 | soligalich
# Processing Record 47 of Set 7 | vagay
# Processing Record 48 of Set 7 | atasu
# Processing Record 49 of Set 7 | boyolangu
# Processing Record 50 of Set 7 | blackwater
# Processing Record 1 of Set 8 | grand island
# Processing Record 2 of Set 8 | naze
# Processing Record 3 of Set 8 | ust-omchug
# Processing Record 4 of Set 8 | teknaf
# Processing Record 5 of Set 8 | laiwu
# Processing Record 6 of Set 8 | rawson
# Processing Record 7 of Set 8 | jutai
# Processing Record 8 of Set 8 | hede
# Processing Record 9 of Set 8 | avera
# Processing Record 10 of Set 8 | noyabrsk
# Processing Record 11 of Set 8 | fukue
# Processing Record 12 of Set 8 | portland
# Processing Record 13 of Set 8 | dakar
# Processing Record 14 of Set 8 | hvide sande
# Processing Record 15 of Set 8 | takoradi
# Processing Record 16 of Set 8 | oistins
# Processing Record 17 of Set 8 | port blair
# Processing Record 18 of Set 8 | nemuro
# Processing Record 19 of Set 8 | nuuk
# Processing Record 20 of Set 8 | taltal
# Processing Record 21 of Set 8 | rio grande
# Processing Record 22 of Set 8 | coquimbo
# Processing Record 23 of Set 8 | amberley
# Processing Record 24 of Set 8 | stornoway
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | kharar
# Processing Record 27 of Set 8 | san felipe
# Processing Record 28 of Set 8 | labuhan
# Processing Record 29 of Set 8 | ureki
# Processing Record 30 of Set 8 | tual
# Processing Record 31 of Set 8 | ceres
# Processing Record 32 of Set 8 | kaitangata
# Processing Record 33 of Set 8 | morwell
# Processing Record 34 of Set 8 | yaguaron
# Processing Record 35 of Set 8 | kainantu
# Processing Record 36 of Set 8 | bahia blanca
# Processing Record 37 of Set 8 | abu dhabi
# Processing Record 38 of Set 8 | belaya
# Processing Record 39 of Set 8 | mukhen
# Processing Record 40 of Set 8 | maceio
# Processing Record 41 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 42 of Set 8 | saint anthony
# Processing Record 43 of Set 8 | mandalgovi
# Processing Record 44 of Set 8 | aranos
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | riyadh
# Processing Record 47 of Set 8 | inirida
# Processing Record 48 of Set 8 | wynyard
# Processing Record 49 of Set 8 | port macquarie
# Processing Record 50 of Set 8 | singkang
# Processing Record 1 of Set 9 | lulea
# Processing Record 2 of Set 9 | aviles
# Processing Record 3 of Set 9 | ambon
# Processing Record 4 of Set 9 | jardim
# Processing Record 5 of Set 9 | osakarovka
# Processing Record 6 of Set 9 | asosa
# Processing Record 7 of Set 9 | mahendranagar
# Processing Record 8 of Set 9 | holbeach
# Processing Record 9 of Set 9 | aykhal
# Processing Record 10 of Set 9 | liniere
# City not found. Skipping...
# Processing Record 11 of Set 9 | balaghat
# Processing Record 12 of Set 9 | paramonga
# Processing Record 13 of Set 9 | kirkkonummi
# Processing Record 14 of Set 9 | hirara
# Processing Record 15 of Set 9 | girona
# Processing Record 16 of Set 9 | hasaki
# Processing Record 17 of Set 9 | champerico
# Processing Record 18 of Set 9 | duluth
# Processing Record 19 of Set 9 | muncar
# Processing Record 20 of Set 9 | camacari
# Processing Record 21 of Set 9 | buta
# Processing Record 22 of Set 9 | tessalit
# Processing Record 23 of Set 9 | bay roberts
# Processing Record 24 of Set 9 | nara
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | bocas del toro
# Processing Record 29 of Set 9 | itarema
# Processing Record 30 of Set 9 | ayame
# Processing Record 31 of Set 9 | chuzhou
# Processing Record 32 of Set 9 | kyren
# Processing Record 33 of Set 9 | chara
# Processing Record 34 of Set 9 | sieut
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | sao joao da barra
# Processing Record 37 of Set 9 | beyneu
# Processing Record 38 of Set 9 | qaqortoq
# Processing Record 39 of Set 9 | fasa
# Processing Record 40 of Set 9 | khuzhir
# Processing Record 41 of Set 9 | rognan
# Processing Record 42 of Set 9 | eureka
# Processing Record 43 of Set 9 | longyearbyen
# Processing Record 44 of Set 9 | karachi
# Processing Record 45 of Set 9 | tambura
# Processing Record 46 of Set 9 | te anau
# Processing Record 47 of Set 9 | zonguldak
# Processing Record 48 of Set 9 | kuala terengganu
# Processing Record 49 of Set 9 | husavik
# Processing Record 50 of Set 9 | verwoerdburg
# City not found. Skipping...
# Processing Record 1 of Set 10 | pangody
# Processing Record 2 of Set 10 | san cristobal
# Processing Record 3 of Set 10 | tasiilaq
# Processing Record 4 of Set 10 | felipe carrillo puerto
# Processing Record 5 of Set 10 | galveston
# Processing Record 6 of Set 10 | zarubino
# Processing Record 7 of Set 10 | lazarev
# Processing Record 8 of Set 10 | byron bay
# Processing Record 9 of Set 10 | opelousas
# Processing Record 10 of Set 10 | havoysund
# Processing Record 11 of Set 10 | iisalmi
# Processing Record 12 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 10 | merauke
# Processing Record 14 of Set 10 | semey
# Processing Record 15 of Set 10 | havelock
# Processing Record 16 of Set 10 | kuli
# Processing Record 17 of Set 10 | morgan city
# Processing Record 18 of Set 10 | ucluelet
# Processing Record 19 of Set 10 | saravan
# Processing Record 20 of Set 10 | logstor
# Processing Record 21 of Set 10 | hengshui
# Processing Record 22 of Set 10 | khani
# Processing Record 23 of Set 10 | trofors
# Processing Record 24 of Set 10 | coari
# Processing Record 25 of Set 10 | syracuse
# Processing Record 26 of Set 10 | enshi
# Processing Record 27 of Set 10 | ambilobe
# Processing Record 28 of Set 10 | esil
# Processing Record 29 of Set 10 | abha
# Processing Record 30 of Set 10 | volnovakha
# Processing Record 31 of Set 10 | shurugwi
# Processing Record 32 of Set 10 | mildura
# Processing Record 33 of Set 10 | bathsheba
# Processing Record 34 of Set 10 | primore
# City not found. Skipping...
# Processing Record 35 of Set 10 | benghazi
# Processing Record 36 of Set 10 | sao felix do xingu
# Processing Record 37 of Set 10 | thyolo
# Processing Record 38 of Set 10 | thinadhoo
# Processing Record 39 of Set 10 | oktyabrskiy
# Processing Record 40 of Set 10 | goundam
# Processing Record 41 of Set 10 | sorong
# Processing Record 42 of Set 10 | bhaderwah
# Processing Record 43 of Set 10 | hobyo
# Processing Record 44 of Set 10 | ningyang
# Processing Record 45 of Set 10 | ulaangom
# Processing Record 46 of Set 10 | tefe
# Processing Record 47 of Set 10 | zarautz
# Processing Record 48 of Set 10 | vestmannaeyjar
# Processing Record 49 of Set 10 | jizan
# Processing Record 50 of Set 10 | lorengau
# Processing Record 1 of Set 11 | novooleksiyivka
# Processing Record 2 of Set 11 | tadpatri
# Processing Record 3 of Set 11 | concordia
# Processing Record 4 of Set 11 | grand forks
# Processing Record 5 of Set 11 | sioux lookout
# Processing Record 6 of Set 11 | manicore
# Processing Record 7 of Set 11 | baykit
# Processing Record 8 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 11 | ahuimanu
# Processing Record 10 of Set 11 | yerbogachen
# Processing Record 11 of Set 11 | surt
# Processing Record 12 of Set 11 | mugla
# Processing Record 13 of Set 11 | grand gaube
# Processing Record 14 of Set 11 | san nicolas
# Processing Record 15 of Set 11 | sinnamary
# Processing Record 16 of Set 11 | montego bay
# Processing Record 17 of Set 11 | homer
# Processing Record 18 of Set 11 | kirakira
# Processing Record 19 of Set 11 | tottori
# Processing Record 20 of Set 11 | sur
# Processing Record 21 of Set 11 | kotelnikovo
# Processing Record 22 of Set 11 | marieville
# Processing Record 23 of Set 11 | kazerun
# Processing Record 24 of Set 11 | iqaluit
# Processing Record 25 of Set 11 | kampong thum
# Processing Record 26 of Set 11 | carauari
# Processing Record 27 of Set 11 | pucara
# Processing Record 28 of Set 11 | baishishan
# Processing Record 29 of Set 11 | mitu
# Processing Record 30 of Set 11 | palana
# Processing Record 31 of Set 11 | bloomingdale
# Processing Record 32 of Set 11 | novolakskoye
# Processing Record 33 of Set 11 | the valley
# Processing Record 34 of Set 11 | rodionovo-nesvetayskaya
# Processing Record 35 of Set 11 | augustow
# Processing Record 36 of Set 11 | tyrma
# Processing Record 37 of Set 11 | menongue
# Processing Record 38 of Set 11 | bethel
# Processing Record 39 of Set 11 | capreol
# Processing Record 40 of Set 11 | los algarrobos
# Processing Record 41 of Set 11 | christchurch
# Processing Record 42 of Set 11 | bud
# Processing Record 43 of Set 11 | senneterre
# Processing Record 44 of Set 11 | preobrazheniye
# Processing Record 45 of Set 11 | poim
# Processing Record 46 of Set 11 | truckee
# Processing Record 47 of Set 11 | jaffna
# Processing Record 48 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 11 | praia
# Processing Record 50 of Set 11 | westport
# Processing Record 1 of Set 12 | mezen
# Processing Record 2 of Set 12 | cherskiy
# Processing Record 3 of Set 12 | kahului
# Processing Record 4 of Set 12 | sindor
# Processing Record 5 of Set 12 | maues
# Processing Record 6 of Set 12 | roza
# Processing Record 7 of Set 12 | anloga
# Processing Record 8 of Set 12 | shimoda
# Processing Record 9 of Set 12 | pishchanka
# City not found. Skipping...
# Processing Record 10 of Set 12 | singapore
# Processing Record 11 of Set 12 | san quintin
# Processing Record 12 of Set 12 | mirabad
# Processing Record 13 of Set 12 | tatarsk
# Processing Record 14 of Set 12 | mullingar
# Processing Record 15 of Set 12 | dalbandin
# Processing Record 16 of Set 12 | bunia
# Processing Record 17 of Set 12 | xichang
# Processing Record 18 of Set 12 | buenos aires
# Processing Record 19 of Set 12 | savannah bight
# Processing Record 20 of Set 12 | magistralnyy
# Processing Record 21 of Set 12 | san jeronimo
# Processing Record 22 of Set 12 | rio gallegos
# Processing Record 23 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 12 | kirkwood
# Processing Record 25 of Set 12 | montefiascone
# Processing Record 26 of Set 12 | tondano
# Processing Record 27 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 28 of Set 12 | mastic beach
# Processing Record 29 of Set 12 | oulainen
# Processing Record 30 of Set 12 | gushikawa
# Processing Record 31 of Set 12 | camana
# Processing Record 32 of Set 12 | carmen
# Processing Record 33 of Set 12 | magadan
# Processing Record 34 of Set 12 | bar
# Processing Record 35 of Set 12 | bykovo
# Processing Record 36 of Set 12 | kavieng
# Processing Record 37 of Set 12 | tura
# Processing Record 38 of Set 12 | valls
# Processing Record 39 of Set 12 | do gonbadan
# Processing Record 40 of Set 12 | hambantota
# Processing Record 41 of Set 12 | santa rosalia
# Processing Record 42 of Set 12 | olafsvik
# Processing Record 43 of Set 12 | mbumi
# Processing Record 44 of Set 12 | akdepe
# Processing Record 45 of Set 12 | mapastepec
# Processing Record 46 of Set 12 | sao jose da coroa grande
# Processing Record 47 of Set 12 | prince rupert
# Processing Record 48 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 49 of Set 12 | valle de allende
# Processing Record 50 of Set 12 | nouadhibou
# Processing Record 1 of Set 13 | nedjo
# Processing Record 2 of Set 13 | santa maria
# Processing Record 3 of Set 13 | canto do buriti
# Processing Record 4 of Set 13 | tautira
# Processing Record 5 of Set 13 | vanavara
# Processing Record 6 of Set 13 | bayji
# Processing Record 7 of Set 13 | payo
# Processing Record 8 of Set 13 | venice
# Processing Record 9 of Set 13 | banyo
# Processing Record 10 of Set 13 | guangyuan
# Processing Record 11 of Set 13 | emiliano zapata
# Processing Record 12 of Set 13 | skjervoy
# Processing Record 13 of Set 13 | hatillo
# Processing Record 14 of Set 13 | bosaso
# Processing Record 15 of Set 13 | musafirkhana
# Processing Record 16 of Set 13 | coria
# Processing Record 17 of Set 13 | tabas
# Processing Record 18 of Set 13 | temyasovo
# Processing Record 19 of Set 13 | miri
# Processing Record 20 of Set 13 | shenzhen
# Processing Record 21 of Set 13 | sironko
# Processing Record 22 of Set 13 | kangaatsiaq
# Processing Record 23 of Set 13 | esperance
# Processing Record 24 of Set 13 | muzhi
# Processing Record 25 of Set 13 | tierranueva
# Processing Record 26 of Set 13 | sangre grande
# Processing Record 27 of Set 13 | pandamatenga
# Processing Record 28 of Set 13 | tabuk
# Processing Record 29 of Set 13 | weinan
# Processing Record 30 of Set 13 | middelburg
# Processing Record 31 of Set 13 | ola
# Processing Record 32 of Set 13 | doorn
# Processing Record 33 of Set 13 | batangafo
# Processing Record 34 of Set 13 | dicabisagan
# Processing Record 35 of Set 13 | abbeville
# Processing Record 36 of Set 13 | kanniyakumari
# Processing Record 37 of Set 13 | bam
# Processing Record 38 of Set 13 | nha trang
# Processing Record 39 of Set 13 | san fernando
# Processing Record 40 of Set 13 | velasco ibarra
# Processing Record 41 of Set 13 | bariri
# Processing Record 42 of Set 13 | yar-sale
# Processing Record 43 of Set 13 | monroe
# Processing Record 44 of Set 13 | kabinda
# Processing Record 45 of Set 13 | saint-paul
# Processing Record 46 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 13 | maudaha
# Processing Record 48 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 49 of Set 13 | molango
# Processing Record 50 of Set 13 | ghatal
# Processing Record 1 of Set 14 | yangjiang
# Processing Record 2 of Set 14 | zhicheng
# Processing Record 3 of Set 14 | chingirlau
# Processing Record 4 of Set 14 | okakarara
# Processing Record 5 of Set 14 | solnechnyy
# Processing Record 6 of Set 14 | ghanzi
# Processing Record 7 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 14 | srostki
# Processing Record 9 of Set 14 | zhuzhou
# Processing Record 10 of Set 14 | staryy nadym
# Processing Record 11 of Set 14 | sinop
# Processing Record 12 of Set 14 | punta cardon
# Processing Record 13 of Set 14 | lujan
# Processing Record 14 of Set 14 | auch
# Processing Record 15 of Set 14 | moron
# Processing Record 16 of Set 14 | de aar
# Processing Record 17 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 14 | caravelas
# Processing Record 19 of Set 14 | tecpan
# Processing Record 20 of Set 14 | marsa matruh
# Processing Record 21 of Set 14 | barrhead
# Processing Record 22 of Set 14 | boguchany
# Processing Record 23 of Set 14 | muisne
# Processing Record 24 of Set 14 | sisimiut
# Processing Record 25 of Set 14 | navapur
# City not found. Skipping...
# Processing Record 26 of Set 14 | hegang
# Processing Record 27 of Set 14 | along
# Processing Record 28 of Set 14 | camacha
# Processing Record 29 of Set 14 | zhezkazgan
# Processing Record 30 of Set 14 | madang
# Processing Record 31 of Set 14 | kyzyl-suu
# Processing Record 32 of Set 14 | san carlos de bariloche
# Processing Record 33 of Set 14 | keelung
# Processing Record 34 of Set 14 | san patricio
# Processing Record 35 of Set 14 | xai-xai
# Processing Record 36 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 14 | suez
# Processing Record 38 of Set 14 | poliyiros
# City not found. Skipping...
# Processing Record 39 of Set 14 | chokwe
# Processing Record 40 of Set 14 | goksun
# Processing Record 41 of Set 14 | fuerte olimpo
# Processing Record 42 of Set 14 | caohe
# Processing Record 43 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 14 | ous
# Processing Record 45 of Set 14 | shache
# Processing Record 46 of Set 14 | talmenka
# Processing Record 47 of Set 14 | do rud
# City not found. Skipping...
# Processing Record 48 of Set 14 | kautokeino
# Processing Record 49 of Set 14 | okha
# Processing Record 50 of Set 14 | zastron
# Processing Record 1 of Set 15 | astana
# Processing Record 2 of Set 15 | college
# Processing Record 3 of Set 15 | hays
# Processing Record 4 of Set 15 | calama
# Processing Record 5 of Set 15 | shetpe
# Processing Record 6 of Set 15 | grande-riviere
# City not found. Skipping...
# Processing Record 7 of Set 15 | nalut
# Processing Record 8 of Set 15 | morant bay
# Processing Record 9 of Set 15 | muroto
# Processing Record 10 of Set 15 | mehamn
# Processing Record 11 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 12 of Set 15 | itoman
# Processing Record 13 of Set 15 | imbituba
# Processing Record 14 of Set 15 | sarankhola
# Processing Record 15 of Set 15 | lithakia
# Processing Record 16 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 15 | salta
# Processing Record 18 of Set 15 | tabou
# Processing Record 19 of Set 15 | behbahan
# Processing Record 20 of Set 15 | buchanan
# Processing Record 21 of Set 15 | canico
# Processing Record 22 of Set 15 | igra
# Processing Record 23 of Set 15 | yarada
# Processing Record 24 of Set 15 | paamiut
# Processing Record 25 of Set 15 | pishin
# Processing Record 26 of Set 15 | bubaque
# Processing Record 27 of Set 15 | ankazoabo
# Processing Record 28 of Set 15 | nome
# Processing Record 29 of Set 15 | bafoulabe
# Processing Record 30 of Set 15 | maneadero
# Processing Record 31 of Set 15 | komsomolskiy
# Processing Record 32 of Set 15 | chapayevka
# Processing Record 33 of Set 15 | egvekinot
# Processing Record 34 of Set 15 | puerto leguizamo
# Processing Record 35 of Set 15 | lagunas
# Processing Record 36 of Set 15 | bilibino
# Processing Record 37 of Set 15 | araouane
# Processing Record 38 of Set 15 | ipixuna
# Processing Record 39 of Set 15 | san gil
# Processing Record 40 of Set 15 | matir
# City not found. Skipping...
# Processing Record 41 of Set 15 | aktash
# Processing Record 42 of Set 15 | omboue
# Processing Record 43 of Set 15 | turayf
# Processing Record 44 of Set 15 | livingston
# Processing Record 45 of Set 15 | porkhov
# Processing Record 46 of Set 15 | shingu
# Processing Record 47 of Set 15 | yate
# Processing Record 48 of Set 15 | piste
# Processing Record 49 of Set 15 | harper
# Processing Record 50 of Set 15 | port hardy
# Processing Record 1 of Set 16 | calamar
# Processing Record 2 of Set 16 | jumla
# Processing Record 3 of Set 16 | hargeysa
# Processing Record 4 of Set 16 | wolmaranstad
# City not found. Skipping...
# Processing Record 5 of Set 16 | saint-denis
# Processing Record 6 of Set 16 | diego de almagro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 700

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Chapais  49.7834  -74.8492     46.18        68         100
# 1    Guerrero Negro  27.9769 -114.0611     71.96        74           0
# 2     Mount Gambier -37.8333  140.7667     65.97        51         100
# 3           Mataura -46.1927  168.8643     52.56        48          69
# 4           Ushuaia -54.8000  -68.3000     44.26        81         100
# 5             Pevek  69.7008  170.3133      4.64        94          70
# 6          Victoria  22.2855  114.1577     72.03        60         100
# 7        Sao Filipe  14.8961  -24.4956     78.58        78         100
# 8           Rikitea -23.1203 -134.9692     68.85        68          61
# 9  Batang Berjuntai   3.3833  101.4167     86.54        82          97
#
#    Wind Speed Country      Current Description
# 0       12.01      CA          overcast clouds
# 1       15.57      MX                clear sky
# 2        7.27      AU          overcast clouds
# 3       10.51      NZ            broken clouds
# 4       12.66      AR  light intensity drizzle
# 5        5.50      RU            broken clouds
# 6       15.99      HK          overcast clouds
# 7        3.78      CV          overcast clouds
# 8       19.86      PF            broken clouds
# 9        1.39      MY          overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
update_column_order= ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[update_column_order]

# Display sample data
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_weather_db = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_weather_db, index_label="City_ID")
